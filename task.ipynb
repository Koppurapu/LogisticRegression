# %%
#importing req 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('traffic.csv')
data
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0         NaN  288.28      0.0      0.0          40        Clouds          1
# 1         NaN  289.36      0.0      0.0          75        Clouds          0
# 2         NaN  289.58      0.0      0.0          90        Clouds          0
# 3         NaN  290.13      0.0      0.0          90        Clouds          0
# 4         NaN  291.14      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds          1
# 48200     NaN  282.76      0.0      0.0          90        Clouds          0
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0         NaN  288.28      0.0      0.0          40        Clouds          1
# 1         NaN  289.36      0.0      0.0          75        Clouds          0
# 2         NaN  289.58      0.0      0.0          90        Clouds          0
# 3         NaN  290.13      0.0      0.0          90        Clouds          0
# 4         NaN  291.14      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds          1
# 48200     NaN  282.76      0.0      0.0          90        Clouds          0
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
# ...

# %%
data.dtypes
# Out:
# holiday            object
# temp              float64
# rain_1h           float64
# snow_1h           float64
# clouds_all          int64
# weather_main       object
# Rush Hour           int64
# traffic_volume      int64
# dtype: object

# %%
#data['holiday'].astype(numeric)

# %%
data.isnull().sum()
# Out:
# holiday           48143
# temp                  0
# rain_1h               0
# snow_1h               0
# clouds_all            0
# weather_main          0
# Rush Hour             0
# traffic_volume        0
# dtype: int64

# %%
data.values
# Out:
# array([[nan, 288.28, 0.0, ..., 'Clouds', 1, 5545],
#        [nan, 289.36, 0.0, ..., 'Clouds', 0, 4516],
#        [nan, 289.58, 0.0, ..., 'Clouds', 0, 4767],
#        ...,
#        [nan, 282.73, 0.0, ..., 'Thunderstorm', 0, 2159],
#        [nan, 282.09, 0.0, ..., 'Clouds', 0, 1450],
#        [nan, 282.12, 0.0, ..., 'Clouds', 0, 954]],
#       shape=(48204, 8), dtype=object)

# %%
figure=plt.figure()
data.boxplot()
plt.plot()
# Out:
# []

# %%
data.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all     Rush Hour  \
# count  48204.000000  48204.000000  48204.000000  48204.000000  48204.000000
# mean     281.205870      0.334264      0.000222     49.362231      0.250124
# std       13.338232     44.789133      0.008168     39.015750      0.433089
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      272.160000      0.000000      0.000000      1.000000      0.000000
# 50%      282.450000      0.000000      0.000000     64.000000      0.000000
# 75%      291.806000      0.000000      0.000000     90.000000      1.000000
# max      310.070000   9831.300000      0.510000    100.000000      1.000000
#
#        traffic_volume
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000

# %%
outlier=
